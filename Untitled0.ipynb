# %% [markdown]
# <a href="https://colab.research.google.com/github/mishkatnaveed14/python_programming_practice/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# this is my first code
print("today we learn python first line !!")
#and ths is my second line
print("and i am very excited for my ai and data science second class !! and i am\n excited to learn my python language basically its not mine now i am learning and understanding the logic\n of python so thats why this time that python is mine!! ")
# ----------strings topic start -------------------
print ("this is my string ")
# ye mera doube quotation string ha or ab single quotation string
print('this is my single quotation string!!')
# and multi line string k liye triple double string ka use krna ha or isse hamay \n ka use nhn krna padta ha bs triple double or single quotations ka use krna hota ha
print(""" Quaid-e-Azam’s Fourteen Points were
a set of constitutional demands presented by Muhammad Ali
Jinnah in March 1929. They served as the Muslim League's reply
to the Nehru Report and aimed to protect the political rights and
 safety of Muslims in British India""")
# if we see slicing in string and the length starts with 1 2 or 3 and the index number starts with 0 ,1 ,2 or etc
string = ("my first slicing string ab mujhe string nikalna ha tu ma dekho ab kese nikalti ho it is very bad") #  isse do concept niklay aik slicing tu jo ham seekh rahay thay isse aik or nikla concept wo ha variable ka matlab variable jese container aap apne string ya kese bhi cheez ko aik jaga pr store kr rhay or bar bar us string ko likhnay k bajaye aap us container ko use kr rahay ho jo aap ne equal se pehle likha tha jese ham aik folder create krtay hain or is ka name my folder rakhtay hain or phr us m apna kam krtay hain magar ab hamay jb bhi kam chahiye hota ha tu ham us ko dobara nhn likhtay balkay ham us ko waha se lete hain jaha ham ne us ko store kia hota ha matlab us container se bolaatay hain jis ka name ham khud rakhtay hain or is ma hamare pas aata ha concept how to name the variable ? or is k liye hamay hamaray variable ka name meaning full rakhna prta ha jese ma ne aik variable banaya python tu us ma sara python ka kam hoga or jb bh python ka kam chhaiye hoga ham python ko bulaye gain or ab hamare pas is ko store kranay kay kuch tareeqay hain jese (1 : ham apnay variable ka name uppercase or lowercase ma rakhenge or starting word uppercase or lowercase or ham underscore(_ => underscore) se bhi rakhsaktay hain )  , (2 : we cant use numbers or integers in start e.g. 1,3,4 like we use in middle or last matlab numbers ko beech ma or aakhir ma likh saktay hain jo legal ha but start ma nhn tu hame error milega which is not legal),(3: or ham koi special symbols jese spaces , hyphen, punctuations[,. ye sb ], or special characters [@#$%^& ye ]) , (4: or A-z , 0-9 , _ bs ye sb Allow ha ), (5: case sensitivity matlab jese agr ham age likhtay hain tu python isse aik alag container samjhe ga or agr ham Age likhtay hain ye bhi alag or doosra variable banay ga or AGE ye bhi alag or doosra container banay ga matlab case sensitivity is very important for python because we learn python so thats why for python but in reality in js and other languages the case sensitivity is lazim or ab hamaray pas isse kuch CASES nikaltay hin jin ko name diya gya ha {1) Snakecase: or wo ye ha k jese har word lowercase ma or jese user_age tu aik se ziyada word k darmiyan underscore for easy to understand} ,{ 2) Pascal case or camel case : vairiable k har name ka first letter capital rahega jese UserProfile etc } or ham upper case snack bhi kr saktay hain jese USER_INTERFACE kuch is type
# i want my word
print(string[0:2]) #isse kia hua isse ye hua k ham jab bhi slicing krtay hain tu ye start hoti ha index number se or index number start hota ha 0 se like 0 1 2 3 aese tu ham ne slicing ma square bracket ka use kr kay us ka starting point bataya jese i want my and my is the first word of string so the slicing pattern is [0 =>(kunkki mujhe m chahye jis ka index number 0 ha ) : =>(ye basically ham is liye use krtay hain jese 0 se mujhe e.g. 4 tk jane k liye beech ma ham colon ka use krtay hain) 2=> agr ham last ma jese 0 : 1 tu ye 1 se hamay bs m milega jb kay hamay my poora chahye tu ham 2 denge index pr ku 2 ye tu 3rd word ka index ha tu slicing ma hame aik word matlab index number jo chahiye hota ha ussse aik number ziyada dena prta ha ] tu is liye ma ne [0:2] likha or b string ma se nikalna ha tu print (string[0:2]) ye likha
# or ab mujhe chahiye slicing word tu lets see
print(string[9:17]) # tu isse new concept kunki ma ne is ma space ko bhi count kiya ha kunki in string space ko character samjha jata ha tu is liye ma ne space ko bhi count kiya
# mujjhe ab is keyword chhaye
print(string[85:87])
# mujhe ab bad chahiye
print(string[92:96])
# tu isse hame ne slicing key or ab ham isse aik kam kregay jese ma chahti hon k ye ali name uppercase ma ho jaye
# yu ma ali name ki slicing ko uppercase ma karogi
# or ye python asynchronoous ha tu hamay doosra string likhna padega
student_name = "My NAME is ali"
print(student_name[11:14].upper()) # ye aik built in function ha upper tu ham is kay end ma parentheses lagana zaroori ha
# aese hi ham lower ma bhi kr saktay hain
lower= student_name[3:7].lower() # ye aik built in function ha lower tu ham is kay end ma parentheses lagana zaroori ha
print(lower)
# or ab ham apnay student name walay se variable ma se dekhna chati hon kitnay characters hain
print(len(student_name))
# ab ham chahtay hain k ham ai para se ma k for example a words kitni bar aaye hain tu ham count method ka use krenge
print(student_name.count("a"))
# Arrays ko ab ham parhenge
message = "hello python crash course"
print(message.title()) #.title aap kay words ka first letter capital krta ha
# combining and concatenating strings
first_name = "muhammad"
last_name = "ali"
full_name = first_name + " " + last_name
print("Hello" + " " + full_name.title() +"How's your day going!!")
print("languages we learn in progamming: \n\tpython\n\tC++\n\tJs")# idher ham ne \n or \t use kia matlab \n matlab new line ya line break \t matlab tab space
# now we use rstrip and lstrip method for extra whitespace `
name = "mishkat "
messages = " would u like to learn some python today?"
print("Hello " + name.title().rstrip() +" " + messages.title().lstrip()) # rstripmethod matlab remove whitespace for right side or lstrip means k whitespace remove krdo left side se
famous_quote_1 = """Albert Einstein once said, "A person who never made a
mistake never tried anything new" """
print(famous_quote_1)
Famous_Person = " albert einstein "
famous_quote_1 = """ once said, "A person who never made a
mistake never tried anything new" """
famous_message = Famous_Person.title().strip() + famous_quote_1 # is ma strip method jo ha wo dono jaga se space remove krdega whitespace for left and right side both
print(famous_message)
# ================== numbers ======================
print(3 + 5)
print(16/2)
print(4 * 2)
print(10-2)
fav_number = 3
print("Your favourite number is " + str(fav_number))
# ===========List==================
names = ["Elon musk" , "ali", "ahad"]
# operators operarator k darmiyan opeartaion perform krne ko operator kehtay hain
# arithmetic operator
# Out:
# hello world
# today we learn python first line !!
# and i am very excited for my ai and data science second class !! and i am
#  excited to learn my python language basically its not mine now i am learning and understanding the logic
#  of python so thats why this time that python is mine!!
# this is my string
# this is my single quotation string!!
#  Quaid-e-Azam’s Fourteen Points were
# a set of constitutional demands presented by Muhammad Ali
# Jinnah in March 1929. They served as the Muslim League's reply
# to the Nehru Report and aimed to protect the political rights and
#  safety of Muslims in British India
# my
# slicing
# is
#  bad
# ALI
# name
# 14
# 1
# Hello Python Crash Course
# Hello Muhammad AliHow's your day going!!
# languages we learn in progamming:
# 	python
# 	C++
# 	Js
# Hello Mishkat Would U Like To Learn Some Python Today?
# Albert Einstein once said, "A person who never made a
# mistake never tried anything new"
# ...
